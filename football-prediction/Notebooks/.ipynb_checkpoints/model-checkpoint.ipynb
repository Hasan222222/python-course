# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

from football_prediction.data_loader import load_and_merge_data
from football_prediction.preprocessing import clean_match_data
from football_prediction.features import create_features, build_team_level_dataset
from football_prediction.model import (
    get_feature_columns,
    prepare_training_data,
    train_poisson_model,
    predict_match,

)

# %%
import importlib
import football_prediction.model as model_module
importlib.reload(model_module)
import numpy as np
import matplotlib.pyplot as plt
import football_prediction.model as model_module

# %%
from football_prediction.model import predict_match_full

# %%
from football_prediction.model import calculate_match_outcome_probabilities

# %%
from football_prediction.model import predict_match_full2

# %%
from football_prediction.model import poisson_pmf

# %%
raw_data = load_and_merge_data("../data/raw")
print(raw_data.shape)
raw_data.head()
# Out:
# (1900, 132)
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... IWA VCH  VCD  VCA  IWCH  IWCD  IWCA  VCCH  VCCD  VCCA
# 0  ... NaN NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ... NaN NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ... NaN NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ... NaN NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ... NaN NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 132 columns]

# %%
clean_data = clean_match_data(raw_data)
print(clean_data.shape)
clean_data.head()
# Out:
# (1900, 6)
#          date   home_team    away_team  home_goals  away_goals result
# 0  16/08/2024  Man United       Fulham           1           0      H
# 1  17/08/2024     Ipswich    Liverpool           0           2      A
# 2  17/08/2024     Arsenal       Wolves           2           0      H
# 3  17/08/2024     Everton     Brighton           0           3      A
# 4  17/08/2024   Newcastle  Southampton           1           0      H

# %%
print(clean_data.columns.tolist())
# Out:
# ['date', 'home_team', 'away_team', 'home_goals', 'away_goals', 'result']

# %%
featured_data = create_features(clean_data)
print(featured_data.shape)
featured_data.head()
# Out:
# (1900, 36)
#         date       home_team    away_team  home_goals  away_goals result  \
# 0 2020-09-12          Fulham      Arsenal           0           3      A
# 1 2020-09-12  Crystal Palace  Southampton           1           0      H
# 2 2020-09-12       Liverpool        Leeds           4           3      H
# 3 2020-09-12        West Ham    Newcastle           0           2      A
# 4 2020-09-13       West Brom    Leicester           0           3      A
#
#    home_avg_goals_scored_last_3  home_avg_goals_conceded_last_3  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    home_avg_points_last_3  home_avg_goal_diff_last_3  ...  \
# 0                     NaN                        NaN  ...
# ...

# %%
team_model_df = build_team_level_dataset(featured_data)
print(team_model_df.shape)
team_model_df.head()
# Out:
# (3800, 32)
#         date         team        opponent  goals  \
# 0 2020-09-12       Fulham         Arsenal      0
# 1 2020-09-12      Arsenal          Fulham      3
# 2 2020-09-12  Southampton  Crystal Palace      0
# 3 2020-09-12        Leeds       Liverpool      3
# 4 2020-09-12    Newcastle        West Ham      2
#
#    team_avg_goals_scored_last_3  team_avg_goals_scored_last_5  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    team_avg_goals_scored_last_10  team_avg_goals_conceded_last_3  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# ...

# %%
print(team_model_df.columns.tolist())
# Out:
# ['date', 'team', 'opponent', 'goals', 'team_avg_goals_scored_last_3', 'team_avg_goals_scored_last_5', 'team_avg_goals_scored_last_10', 'team_avg_goals_conceded_last_3', 'team_avg_goals_conceded_last_5', 'team_avg_goals_conceded_last_10', 'team_avg_points_last_3', 'team_avg_points_last_5', 'team_avg_points_last_10', 'team_avg_goal_diff_last_3', 'team_avg_goal_diff_last_5', 'team_avg_goal_diff_last_10', 'opp_avg_goals_scored_last_3', 'opp_avg_goals_scored_last_5', 'opp_avg_goals_scored_last_10', 'opp_avg_goals_conceded_last_3', 'opp_avg_goals_conceded_last_5', 'opp_avg_goals_conceded_last_10', 'opp_avg_points_last_3', 'opp_avg_points_last_5', 'opp_avg_points_last_10', 'opp_avg_goal_diff_last_3', 'opp_avg_goal_diff_last_5', 'opp_avg_goal_diff_last_10', 'venue_avg_goals_scored_last_5', 'venue_avg_goals_conceded_last_5', 'venue_avg_points_last_5', 'is_home']

# %%
feature_cols = get_feature_columns()
print(feature_cols)
# Out:
# ['team_avg_goals_scored_last_5', 'opp_avg_goals_scored_last_5', 'team_avg_points_last_5', 'opp_avg_points_last_5']

# %%
X, y = prepare_training_data(team_model_df)

print("X shape:", X.shape)
print("y shape:", y.shape)

display(X.head())
display(y.head())
# Out:
# X shape: (3762, 4)
# y shape: (3762,)
#     team_avg_goals_scored_last_5  opp_avg_goals_scored_last_5  \
# 16                           0.0                          3.0
# 17                           0.0                          1.0
# 18                           0.0                          3.0
# 19                           3.0                          0.0
# 21                           3.0                          0.0
#
#     team_avg_points_last_5  opp_avg_points_last_5
# 16                     0.0                    3.0
# 17                     0.0                    3.0
# 18                     0.0                    0.0
# 19                     0.0                    0.0
# 21                     3.0                    0.0
# 16    1
# 17    2
# 18    3
# 19    4
# 21    2
# Name: goals, dtype: int64

# %%
model, X_train_full, y_train_full = train_poisson_model(team_model_df)

# %%
train_pred = model.predict(X_train_full)
mae = mean_absolute_error(y_train_full, train_pred)

print("Trainings-MAE:", mae)
# Out:
# Trainings-MAE: 1.0120247190695302

# %%
print("Features im Modell:")
print(list(model.feature_names_in_))

print("Features laut get_feature_columns():")
print(get_feature_columns())

print("Identisch?:", list(model.feature_names_in_) == get_feature_columns())
# Out:
# Features im Modell:
# ['team_avg_goals_scored_last_5', 'opp_avg_goals_scored_last_5', 'team_avg_points_last_5', 'opp_avg_points_last_5']
# Features laut get_feature_columns():
# ['team_avg_goals_scored_last_5', 'opp_avg_goals_scored_last_5', 'team_avg_points_last_5', 'opp_avg_points_last_5']
# Identisch?: True

# %%
result = predict_match(
    model=model,
    team_model_df=team_model_df,
    home_team="Arsenal",
    away_team="Chelsea",
)

result
# Out:
# {'home_team': 'Arsenal',
#  'away_team': 'Chelsea',
#  'predicted_home_goals': 1.406988518669389,
#  'rounded_home_goals': 1}

# %%
print(f"Heimteam: {result['home_team']}")
print(f"Auswärtsteam: {result['away_team']}")
print(f"Vorhergesagte Heimtore: {result['predicted_home_goals']:.2f}")
print(f"Gerundete Heimtore: {result['rounded_home_goals']}")
# Out:
# Heimteam: Arsenal
# Auswärtsteam: Chelsea
# Vorhergesagte Heimtore: 1.41
# Gerundete Heimtore: 1

# %%
home_df = team_model_df[team_model_df["is_home"] == 1]
away_df = team_model_df[team_model_df["is_home"] == 0]

home_model, X_home, y_home = train_poisson_model(home_df)
away_model, X_away, y_away = train_poisson_model(away_df)

# %%
result = predict_match_full(
    home_model=home_model,
    away_model=away_model,
    team_model_df=team_model_df,
    home_team="Arsenal",
    away_team="Chelsea",
)

print(result)
# Out:
# {'home_team': 'Arsenal', 'away_team': 'Chelsea', 'predicted_home_goals': 1.5199101504708277, 'predicted_away_goals': 1.3439136880398959, 'rounded_home_goals': 2, 'rounded_away_goals': 1, 'winner': 'Arsenal'}

# %%
result = predict_match_full(
    home_model=home_model,
    away_model=away_model,
    team_model_df=team_model_df,
    home_team="Arsenal",
    away_team="Chelsea",
)

print(result)
# Out:
# {'home_team': 'Arsenal', 'away_team': 'Chelsea', 'predicted_home_goals': 1.5199101504708277, 'predicted_away_goals': 1.3439136880398959, 'rounded_home_goals': 2, 'rounded_away_goals': 1, 'winner': 'Arsenal'}

# %%
print(f"{result['home_team']} vs {result['away_team']}")
print(f"Erwartet: {result['predicted_home_goals']:.2f} : {result['predicted_away_goals']:.2f}")
print(f"Ergebnis: {result['rounded_home_goals']} : {result['rounded_away_goals']}")
print(f"Sieger: {result['winner']}")
# Out:
# Arsenal vs Chelsea
# Erwartet: 1.52 : 1.34
# Ergebnis: 2 : 1
# Sieger: Arsenal

# %%
result = predict_match_full2(
    home_model=home_model,
    away_model=away_model,
    team_model_df=team_model_df,
    home_team="Arsenal",
    away_team="Chelsea",
)

print(f"{result['home_team']} vs {result['away_team']}")
print(f"Erwartete Tore: {result['predicted_home_goals']:.2f} : {result['predicted_away_goals']:.2f}")
print(f"Gerundetes Ergebnis: {result['rounded_home_goals']} : {result['rounded_away_goals']}")
print(f"Sieger-Tipp: {result['winner']}")
print()
print(f"Wahrscheinlichkeit Heimsieg: {result['home_win_probability']:.2%}")
print(f"Wahrscheinlichkeit Unentschieden: {result['draw_probability']:.2%}")
print(f"Wahrscheinlichkeit Auswärtssieg: {result['away_win_probability']:.2%}")
# Out:
# Arsenal vs Chelsea
# Erwartete Tore: 1.52 : 1.34
# Gerundetes Ergebnis: 2 : 1
# Sieger-Tipp: Arsenal
#
# Wahrscheinlichkeit Heimsieg: 41.52%
# Wahrscheinlichkeit Unentschieden: 24.85%
# Wahrscheinlichkeit Auswärtssieg: 33.63%

# %%
labels = ["Heimsieg", "Unentschieden", "Auswärtssieg"]
values = [
    result["home_win_probability"],
    result["draw_probability"],
    result["away_win_probability"],
]

plt.figure(figsize=(8, 5))
plt.bar(labels, values)
plt.ylabel("Wahrscheinlichkeit")
plt.ylim(0, 1)
plt.title(f"Ergebniswahrscheinlichkeiten: {result['home_team']} vs {result['away_team']}")
plt.show()

# %%
max_goals_plot = 5
score_matrix = np.zeros((max_goals_plot + 1, max_goals_plot + 1))

for (home_goals, away_goals), prob in result["score_probabilities"].items():
    if home_goals <= max_goals_plot and away_goals <= max_goals_plot:
        score_matrix[home_goals, away_goals] = prob

plt.figure(figsize=(8, 6))
plt.imshow(score_matrix, origin="lower", aspect="auto")
plt.colorbar(label="Wahrscheinlichkeit")
plt.xticks(range(max_goals_plot + 1))
plt.yticks(range(max_goals_plot + 1))
plt.xlabel(f"Tore {result['away_team']}")
plt.ylabel(f"Tore {result['home_team']}")
plt.title(f"Heatmap exakter Ergebnisse: {result['home_team']} vs {result['away_team']}")
plt.show()

# %%
home_lambda = result["predicted_home_goals"]
goals = list(range(0, 8))
home_probs = [model_module.poisson_pmf(k, home_lambda) for k in goals]

plt.figure(figsize=(8, 5))
plt.bar(goals, home_probs)
plt.xlabel(f"Tore {result['home_team']}")
plt.ylabel("Wahrscheinlichkeit")
plt.title(f"Poisson-Verteilung Heimtore: {result['home_team']}")
plt.xticks(goals)
plt.show()

# %%
away_lambda = result["predicted_away_goals"]
goals = list(range(0, 8))
away_probs = [model_module.poisson_pmf(k, away_lambda) for k in goals]

plt.figure(figsize=(8, 5))
plt.bar(goals, away_probs)
plt.xlabel(f"Tore {result['away_team']}")
plt.ylabel("Wahrscheinlichkeit")
plt.title(f"Poisson-Verteilung Auswärtstore: {result['away_team']}")
plt.xticks(goals)
plt.show()

# %%
## 1. Wissenschaftliche Fragestellung

### Sind Tore des Heimteams besser vorhersagbar als Auswärtstore?

Zur Beantwortung dieser Frage wird die Vorhersagegüte der beiden separat trainierten Poisson-Modelle verglichen.  
Dazu werden die tatsächlichen Tore mit den vorhergesagten Toren für Heim- und Auswärtsteams getrennt betrachtet.  
Als Gütemaße werden der Mean Absolute Error (MAE) und die Root Mean Squared Error (RMSE) verwendet.

Ein kleinerer Fehler bedeutet eine bessere Vorhersagbarkeit.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Vorhersagen der beiden Modelle
home_pred = home_model.predict(X_home)
away_pred = away_model.predict(X_away)

# Fehlermaße berechnen
mae_home = mean_absolute_error(y_home, home_pred)
mae_away = mean_absolute_error(y_away, away_pred)

rmse_home = np.sqrt(mean_squared_error(y_home, home_pred))
rmse_away = np.sqrt(mean_squared_error(y_away, away_pred))

print("Vorhersagegüte Heimtore")
print(f"MAE Heimtore:  {mae_home:.3f}")
print(f"RMSE Heimtore: {rmse_home:.3f}")
print()
print("Vorhersagegüte Auswärtstore")
print(f"MAE Auswärtstore:  {mae_away:.3f}")
print(f"RMSE Auswärtstore: {rmse_away:.3f}")

if mae_home < mae_away:
    print("\nErgebnis: Heimtore sind anhand des MAE besser vorhersagbar als Auswärtstore.")
elif mae_home > mae_away:
    print("\nErgebnis: Auswärtstore sind anhand des MAE besser vorhersagbar als Heimtore.")
else:
    print("\nErgebnis: Heim- und Auswärtstore sind anhand des MAE gleich gut vorhersagbar.")
# Out:
# Vorhersagegüte Heimtore
# MAE Heimtore:  1.043
# RMSE Heimtore: 1.308
#
# Vorhersagegüte Auswärtstore
# MAE Auswärtstore:  0.965
# RMSE Auswärtstore: 1.212
#
# Ergebnis: Auswärtstore sind anhand des MAE besser vorhersagbar als Heimtore.

# %%
### Interpretation

Die Ergebnisse zeigen, dass die Vorhersagefehler für Auswärtstore etwas kleiner sind als für
Heimtore. Der Mean Absolute Error beträgt für Heimtore 1.043, während er für 
Auswärtstore bei 0.965 liegt. Auch beim RMSE ergibt sich dasselbe Bild: Für Heimtore liegt er 
bei 1.308, für Auswärtstore bei 1.212.

Damit sind Auswärtstore im vorliegenden Datensatz geringfügig besser vorhersagbar als Heimtore.  
Dieses Ergebnis ist zunächst etwas überraschend, da im Fußball häufig von einem Heimvorteil
ausgegangen wird. Möglicherweise zeigen Heimteams zwar im Durchschnitt stärkere Leistungen, 
gleichzeitig aber auch größere Schwankungen, die durch die verwendeten Merkmale nicht vollständig 
erfasst werden. Die Auswärtstore scheinen im gewählten Modell dagegen etwas stabiler 
modellierbar zu sein.

# %%
### Fazit zur wissenschaftlichen Fragestellung

Die Analyse liefert keine Evidenz dafür, dass Heimtore besser vorhersagbar sind als Auswärtstore.  
Vielmehr zeigen die berechneten Fehlermaße, dass Auswärtstore im verwendeten Modell geringfügig 
präziser vorhergesagt werden. Der Unterschied ist nicht sehr groß, deutet jedoch darauf hin, 
dass die Vorhersagbarkeit von Heim- und Auswärtstoren nicht zwingend mit dem klassischen 
Heimvorteil übereinstimmt.

# %%
## 2. Wissenschaftliche Fragestellung

### Wie gut passt die Poisson-Verteilung zu den tatsächlichen Toren?

Zur Beantwortung dieser Frage wird die beobachtete Verteilung der erzielten Tore mit einer theoretischen Poisson-Verteilung verglichen.  
Dazu werden für Heim- und Auswärtstore jeweils die empirischen Häufigkeiten den entsprechenden Poisson-Wahrscheinlichkeiten gegenübergestellt.  
Zusätzlich werden Mittelwert und Varianz der Torverteilungen verglichen, da bei einer idealen Poisson-Verteilung beide Größen ungefähr übereinstimmen.

Eine gute Übereinstimmung zwischen beobachteter und theoretischer Verteilung spricht dafür, dass die Poisson-Annahme für die Modellierung von Fußballtoren geeignet ist.

# %%
import numpy as np
import pandas as pd

home_goals = clean_data["home_goals"]
away_goals = clean_data["away_goals"]

home_mean = home_goals.mean()
home_var = home_goals.var()

away_mean = away_goals.mean()
away_var = away_goals.var()

print("Heimtore")
print(f"Mittelwert: {home_mean:.3f}")
print(f"Varianz:   {home_var:.3f}")
print()

print("Auswärtstore")
print(f"Mittelwert: {away_mean:.3f}")
print(f"Varianz:   {away_var:.3f}")
# Out:
# Heimtore
# Mittelwert: 1.563
# Varianz:   1.822
#
# Auswärtstore
# Mittelwert: 1.353
# Varianz:   1.528

# %%
import math
import matplotlib.pyplot as plt

def poisson_pmf(k, lam):
    return math.exp(-lam) * (lam ** k) / math.factorial(k)

max_goals = int(max(clean_data["home_goals"].max(), clean_data["away_goals"].max()))
goal_range = list(range(max_goals + 1))

# Beobachtete relative Häufigkeiten
obs_home = clean_data["home_goals"].value_counts(normalize=True).sort_index()
obs_home = [obs_home.get(k, 0) for k in goal_range]

# Theoretische Poisson-Wahrscheinlichkeiten
pois_home = [poisson_pmf(k, home_mean) for k in goal_range]

plt.figure(figsize=(8, 5))
plt.bar(goal_range, obs_home, alpha=0.7, label="Beobachtet")
plt.plot(goal_range, pois_home, marker="o", label="Poisson")
plt.xlabel("Anzahl Heimtore")
plt.ylabel("Wahrscheinlichkeit")
plt.title("Heimtore: Beobachtete Verteilung vs. Poisson-Verteilung")
plt.xticks(goal_range)
plt.legend()
plt.show()

# %%
obs_away = clean_data["away_goals"].value_counts(normalize=True).sort_index()
obs_away = [obs_away.get(k, 0) for k in goal_range]

pois_away = [poisson_pmf(k, away_mean) for k in goal_range]

plt.figure(figsize=(8, 5))
plt.bar(goal_range, obs_away, alpha=0.7, label="Beobachtet")
plt.plot(goal_range, pois_away, marker="o", label="Poisson")
plt.xlabel("Anzahl Auswärtstore")
plt.ylabel("Wahrscheinlichkeit")
plt.title("Auswärtstore: Beobachtete Verteilung vs. Poisson-Verteilung")
plt.xticks(goal_range)
plt.legend()
plt.show()

# %%
### Interpretation

Der Vergleich zwischen beobachteter Torverteilung und theoretischer Poisson-Verteilung zeigt insgesamt eine gute Übereinstimmung.  
Sowohl für Heimtore als auch für Auswärtstore folgt die beobachtete Verteilung dem typischen Verlauf der Poisson-Verteilung recht nah.

Besonders im Bereich der häufigen Torzahlen stimmen beobachtete und theoretische Wahrscheinlichkeiten sehr gut überein.  
Aber auch bei höheren Torzahlen ist der generelle Verlauf ähnlich, sodass die Poisson-Verteilung die Daten insgesamt gut approximiert.

Der Vergleich von Mittelwert und Varianz zeigt allerdings, dass die Varianz jeweils etwas größer ist als der Mittelwert.  
Dies weist auf eine leichte Überdispersion hin.  
Die Poisson-Annahme ist damit nicht perfekt erfüllt, stellt für die vorliegenden Fußballdaten aber insgesamt eine sinnvolle und gut passende Modellgrundlage dar.

# %%
### Fazit zur wissenschaftlichen Fragestellung

Die Poisson-Verteilung passt insgesamt gut zu den tatsächlich beobachteten Toren.  
Die grafischen Vergleiche zeigen sowohl für Heim- als auch für Auswärtstore eine deutliche Nähe zwischen beobachteter und theoretischer Verteilung.

Zwar ist die Varianz jeweils etwas größer als der Mittelwert, sodass die Poisson-Annahme nicht exakt erfüllt ist.  
Die Abweichungen sind jedoch eher klein.  
Insgesamt ist die Poisson-Verteilung daher eine gut geeignete Grundlage zur Modellierung von Fußballtoren in diesem Datensatz.
