# %%
from football_prediction.data_loader import load_and_merge_data
from football_prediction.preprocessing import clean_match_data
from football_prediction.features import create_features

# %%
data = load_and_merge_data("../data/raw")
data = clean_match_data(data)
data = create_features(data)

data.head()
# Out:
#         date       home_team    away_team  home_goals  away_goals result  \
# 0 2020-09-12          Fulham      Arsenal           0           3      A
# 1 2020-09-12  Crystal Palace  Southampton           1           0      H
# 2 2020-09-12       Liverpool        Leeds           4           3      H
# 3 2020-09-12        West Ham    Newcastle           0           2      A
# 4 2020-09-13       West Brom    Leicester           0           3      A
#
#    home_avg_goals_scored_last_5  home_avg_goals_conceded_last_5  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    home_avg_points_last_5  away_avg_goals_scored_last_5  \
# 0                     NaN                           NaN
# 1                     NaN                           NaN
# 2                     NaN                           NaN
# 3                     NaN                           NaN
# 4                     NaN                           NaN
#
#    away_avg_goals_conceded_last_5  away_avg_points_last_5
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1900 entries, 0 to 1899
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            1900 non-null   datetime64[us]
#  1   home_team                       1900 non-null   str
#  2   away_team                       1900 non-null   str
#  3   home_goals                      1900 non-null   int64
#  4   away_goals                      1900 non-null   int64
#  5   result                          1900 non-null   str
#  6   home_avg_goals_scored_last_5    1885 non-null   float64
#  7   home_avg_goals_conceded_last_5  1885 non-null   float64
#  8   home_avg_points_last_5          1885 non-null   float64
#  9   away_avg_goals_scored_last_5    1888 non-null   float64
#  10  away_avg_goals_conceded_last_5  1888 non-null   float64
#  11  away_avg_points_last_5          1888 non-null   float64
# dtypes: datetime64[us](1), float64(6), int64(2), str(3)
# memory usage: 178.3 KB

# %%
data[[
    "home_team",
    "away_team",
    "home_avg_goals_scored_last_5",
    "away_avg_goals_scored_last_5",
    "home_avg_points_last_5",
    "away_avg_points_last_5"
]].head(10)
# Out:
#           home_team       away_team  home_avg_goals_scored_last_5  \
# 0            Fulham         Arsenal                           NaN
# 1    Crystal Palace     Southampton                           NaN
# 2         Liverpool           Leeds                           NaN
# 3          West Ham       Newcastle                           NaN
# 4         West Brom       Leicester                           NaN
# 5         Tottenham         Everton                           NaN
# 6          Brighton         Chelsea                           NaN
# 7  Sheffield United          Wolves                           NaN
# 8           Arsenal        West Ham                           3.0
# 9        Man United  Crystal Palace                           NaN
#
#    away_avg_goals_scored_last_5  home_avg_points_last_5  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# 5                           NaN                     NaN
# 6                           NaN                     NaN
# 7                           NaN                     NaN
# 8                           0.0                     3.0
# 9                           1.0                     NaN
#
#    away_avg_points_last_5
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     0.0
# 9                     3.0
